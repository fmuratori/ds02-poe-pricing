# %%
import sys
import time

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.sparse import lil_matrix

sys.path.append('../../../')
from poe_price.data.access.session import PSQLSession

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Trading currencies rates

# %%
with PSQLSession('127.0.0.1', 'poe_price', 'fabio', 'password') as session:
    currency = session.query('SELECT * FROM trade_currency;')

currency['rate'] = currency.sell_quantity / currency.price_quantity

# %%
OUTLIER_WINDOW = 1    # remove trades rate which value is outside the normal distribution window 
                      # defined as (mean_value +- standard deviation * OUTLIER_WINDOW)

MARKET_HEAD = 20      # select only the top MARKET_HEAD deals for the buyer: those deals most
                      # likely are the most representative and older records are ignored

# %%
currencies = set(set(currency.sell_currency.values) & 
                 set(currency.price_currency.values))

c_rates = pd.DataFrame(index=set(currency.price_currency.values), 
                       columns=set(currency.price_currency.values))

# %%
for v1 in currencies:
    for v2 in set(currencies - set(v1)):
        
        if v1 == 'chaos' or v2 == 'chaos':
            temp = currency[(currency.sell_currency==v1) & 
                            (currency.price_currency==v2)].copy()
            temp.sort_values('rate', ascending=False, inplace=True)

            rate_std = temp.rate.std()
            rate_mean = temp.rate.mean()
            temp['n_rate'] = temp.rate.apply(lambda y: 
                                             (y - rate_mean) / rate_std)

            f_rate = temp[(temp.n_rate > -OUTLIER_WINDOW) & 
                          (temp.n_rate < OUTLIER_WINDOW)].rate

            c_rates.loc[v1, v2] = round(np.mean(temp.head(MARKET_HEAD).rate), 3)
c_rates
# Out:
#          scour silver   fuse  chrom    gcp chisel     exa  regal chance  \
# scour      NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# silver     NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# fuse       NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# chrom      NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# gcp        NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# chisel     NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# exa        NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# regal      NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# chance     NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# vaal       NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# chaos    0.363  0.092  0.375  0.133  1.161  0.234  115.23  0.271  0.068
# alch       NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# divine     NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# blessed    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# jew        NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# regret     NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
# alt        NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN    NaN
#
#           vaal   chaos   alch divine blessed    jew regret    alt
# scour      NaN    3.04    NaN    NaN     NaN    NaN    NaN    NaN
# silver     NaN  10.476    NaN    NaN     NaN    NaN    NaN    NaN
# fuse       NaN   3.096    NaN    NaN     NaN    NaN    NaN    NaN
# chrom      NaN   7.869    NaN    NaN     NaN    NaN    NaN    NaN
# gcp        NaN   0.791    NaN    NaN     NaN    NaN    NaN    NaN
# chisel     NaN   4.422    NaN    NaN     NaN    NaN    NaN    NaN
# exa        NaN   0.009    NaN    NaN     NaN    NaN    NaN    NaN
# regal      NaN   3.285    NaN    NaN     NaN    NaN    NaN    NaN
# chance     NaN  12.404    NaN    NaN     NaN    NaN    NaN    NaN
# vaal       NaN   2.711    NaN    NaN     NaN    NaN    NaN    NaN
# chaos    0.301     NaN  0.218   9.78   0.031  0.088  0.471  0.883
# alch       NaN   5.008    NaN    NaN     NaN    NaN    NaN    NaN
# divine     NaN   0.108    NaN    NaN     NaN    NaN    NaN    NaN
# blessed    NaN  14.202    NaN    NaN     NaN    NaN    NaN    NaN
# jew        NaN  11.445    NaN    NaN     NaN    NaN    NaN    NaN
# regret     NaN   2.013    NaN    NaN     NaN    NaN    NaN    NaN
# alt        NaN   4.056    NaN    NaN     NaN    NaN    NaN    NaN

# %%
c_rates.loc['chaos', :] * c_rates.loc[:, 'chaos']
# Out:
# scour       1.10352
# silver     0.963792
# fuse          1.161
# chrom       1.04658
# gcp        0.918351
# chisel      1.03475
# exa         1.03707
# regal      0.890235
# chance     0.843472
# vaal       0.816011
# chaos           NaN
# alch        1.09174
# divine      1.05624
# blessed    0.440262
# jew         1.00716
# regret     0.948123
# alt         3.58145
# Name: chaos, dtype: object

# %% [markdown]
# # Features extraction

# %%
with PSQLSession('localhost', 'poe_price', 'fabio', 'password') as session:
    items = session.query('''
        SELECT * 
        FROM trade_item 
        WHERE category = 'weapons';''')

    items_modifiers = session.query('''
        SELECT tim.* 
        FROM trade_item as ti, trade_item_modifier as tim
        WHERE ti.id = tim.item_id
        AND ti.category = 'weapons';
        ''')
    
    items_properties = session.query('''
        SELECT tip.* 
        FROM trade_item as ti, trade_item_property as tip
        WHERE ti.id = tip.item_id
        AND ti.category = 'weapons';
        ''')
        
    items_sockets = session.query('''
        SELECT tis.* 
        FROM trade_item as ti, trade_item_socket as tis
        WHERE ti.id = tis.item_id
        AND ti.category = 'weapons';
        ''')

# %%
items_f = items.copy()

# %%
items_f.sample(10)
# Out:
#            id category corrupted duplicated  identified  ilvl  \
# 48232  396789  weapons      None       None        True    71
# 73744  606524  weapons      True       None        True    50
# 66247  546010  weapons      None       None       False    67
# 67671  558177  weapons      None       None        True    78
# 51750  426142  weapons      None       None        True    24
# 57076  471754  weapons      None       None        True    83
# 13069  113687  weapons      None       None        True    80
# 42852  352962  weapons      None       None        True    75
# 76512  629459  weapons      None       None        True    82
# 45008  370606  weapons      None       None        True    80
#
#       influence_crusader influence_elder influence_hunter influence_redeemer  \
# 48232               None            None             None               None
# 73744               None            None             None               None
# 66247               None            None             None               None
# 67671               None            True             None               None
# 51750               None            None             None               None
# 57076               None            True             None               None
# 13069               None            None             None               None
# 42852               None            None             None               None
# 76512               None            None             None               None
# 45008               None            None             None               None
#
#       influence_shaper influence_warlord    league  num_prefixes  \
# 48232             None              None  Delirium           1.0
# 73744             None              None  Delirium           2.0
# 66247             None              None  Delirium           NaN
# 67671             None              None  Delirium           2.0
# 51750             None              None  Delirium           1.0
# 57076             None              None  Delirium           3.0
# 13069             None              None  Delirium           3.0
# 42852             None              None  Delirium           3.0
# 76512             None              None  Delirium           2.0
# 45008             None              None  Delirium           2.0
#
#        num_suffixes  num_veiled_modifiers price_currency  price_quantity  \
# 48232           1.0                   0.0           alch               1
# 73744           2.0                   0.0          chaos              20
# 66247           NaN                   0.0          chaos               1
# 67671           3.0                   0.0            exa               1
# 51750           3.0                   0.0            alt               1
# 57076           3.0                   0.0          chaos              20
# 13069           2.0                   0.0          chaos               5
# 42852           2.0                   0.0          chaos               4
# 76512           3.0                   0.0          chaos              15
# 45008           2.0                   0.0          chaos               5
#
#       rarity  requirement_dex  requirement_int  requirement_str  \
# 48232  magic             43.0              NaN            151.0
# 73744   rare             26.0              NaN              NaN
# 66247   rare            170.0              NaN              NaN
# 67671   rare            121.0              NaN              NaN
# 51750   rare              NaN             83.0              NaN
# 57076   rare            119.0              NaN            119.0
# 13069   rare              NaN            188.0              NaN
# 42852   rare              NaN            188.0              NaN
# 76512   rare              NaN            237.0              NaN
# 45008   rare              NaN            212.0              NaN
#
#        requirement_level sub_category synthesised talisman_tier        date
# 48232               58.0       twoaxe        None          None  03/29/2020
# 73744               64.0          bow        None          None  03/29/2020
# 66247                NaN          bow        None          None  03/29/2020
# 67671               56.0          bow        None          None  03/29/2020
# 51750               24.0         wand        None          None  03/29/2020
# 57076               70.0     onesword        None          None  03/29/2020
# 13069               59.0         wand        None          None  03/29/2020
# 42852               59.0         wand        None          None  03/29/2020
# 76512               70.0         wand        None          None  03/29/2020
# 45008               62.0         wand        None          None  03/29/2020

# %%
for col_name in ['corrupted', 'duplicated', 'influence_crusader', 'influence_elder',
         'influence_hunter', 'influence_redeemer', 'influence_shaper', 
         'influence_warlord']:
    items_f[col_name].fillna(False, inplace=True)

for col_name in ['num_veiled_modifiers', 'requirement_dex', 'requirement_int', 'requirement_str', 'requirement_level']:
    items_f[col_name].fillna(0, inplace=True)

# %%
def map_price(y):
    return c_rates.loc['chaos', currency] * quantity

price = []
for k, v in items_f.iterrows():
    if v.price_currency != 'chaos':
        price.append(c_rates.loc['chaos', v.price_currency] * v.price_quantity)
    else:
        price.append(v.price_quantity)
items_f['price'] = price

# %%
# %%time
how = 'value'
        
mod_lut = {pid: i for i, pid in enumerate(sorted(set(items_modifiers.modifier_id.values)))}
mod_fm = lil_matrix((items_f.shape[0], len(mod_lut)))
for i, wid in enumerate(items_f.id.values):
    for pid, mod in items_modifiers[items_modifiers.item_id == wid].iterrows():
        values = [v for v in [mod.value0, mod.value1, mod.value2] if ~np.isnan(v)]
        if len(values) > 0 and how == 'value':
            values = np.mean(values)
        elif len(values) == 0 or how == 'flag':
            values = 1
        mod_fm[i, mod_lut[mod.modifier_id]] = values
        
items_f = pd.concat([items_f, pd.DataFrame(mod_fm.todense(), columns=['mod{}'.format(i) for i in range(len(mod_lut))])], axis=1)
# Out:
# CPU times: user 3min 40s, sys: 554 ms, total: 3min 41s
# Wall time: 3min 41s

# %%
# %%time
how = 'value'

prop_lut = {pid: i for i, pid in enumerate(sorted(set(items_properties.property_id.values)))}
prop_fm = lil_matrix((items_f.shape[0], len(prop_lut)))
for i, wid in enumerate(items_f.id.values):
    for pid, prop in items_properties[items_properties.item_id == wid].iterrows():
        values = [v for v in [prop.value0, prop.value1] if ~np.isnan(v)]
        if len(values) > 0 and how == 'value':
            values = np.mean(values)
        elif len(values) == 0 or how == 'flag':
            values = 1
        prop_fm[i, prop_lut[prop.property_id]] = values
        
items_f = pd.concat([items_f, pd.DataFrame(prop_fm.todense(), columns=['prop{}'.format(i) for i in range(len(prop_lut))])], axis=1)
# Out:
# CPU times: user 2min 31s, sys: 236 ms, total: 2min 31s
# Wall time: 2min 31s

# %%
# %%time 
items_f['n_sockets'] = 0
items_f['n_red_sockets'] = 0
items_f['n_green_sockets'] = 0
items_f['n_blue_sockets'] = 0
items_f['n_white_sockets'] = 0
items_f['n_abyss_sockets'] = 0
items_f['n_links'] = 0

sockets = None
for iid in items_f.id.values:
    sockets = items_sockets[items_sockets.item_id == iid]
    scolors = sockets.colour.value_counts()
    items_f.at[k, 'n_sockets'] = sockets.shape[0]
    items_f.at[k, 'n_red_sockets'] = scolors['R'] if 'R' in scolors else 0
    items_f.at[k, 'n_green_sockets'] = scolors['G'] if 'G' in scolors else 0
    items_f.at[k, 'n_blue_sockets'] = scolors['B'] if 'B' in scolors else 0
    items_f.at[k, 'n_white_sockets'] = scolors['W'] if 'W' in scolors else 0
    items_f.at[k, 'n_abyss_sockets'] = scolors['A'] if 'A' in scolors else 0
    items_f.at[k, 'n_links'] = sockets.socket_group.value_counts().iloc[0]
# Out:
# CPU times: user 3min 43s, sys: 128 ms, total: 3min 43s
# Wall time: 3min 43s

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

rarity_le = LabelEncoder()
rarity_le.fit(['normal', 'magic', 'rare'])
items_f.rarity = rarity_le.transform(items_f.rarity)

tf_le = LabelEncoder()
tf_le.fit([True, False])
for col_name in ['corrupted', 'duplicated', 'identified', 'influence_crusader', 'influence_elder',
         'influence_hunter', 'influence_redeemer', 'influence_shaper', 
         'influence_warlord']:
    items_f[col_name] = tf_le.transform(items_f[col_name])

# %%
subcategory_ohe = OneHotEncoder(sparse=False)

items_f = pd.concat([items_f, pd.DataFrame(subcategory_ohe.fit_transform(items_f.sub_category.values.reshape(-1,1)), 
             columns=['category{}'.format(i) 
                      for i in range(len(subcategory_ohe.get_feature_names()))])], axis=1)

# %%
for col in items_f.columns:
    if len(items_f.loc[:, col].value_counts(dropna=False)) == 1:
        del(items_f[col])
        
items_f.drop(columns=['id', 'category', 'date', 'price_currency', 'price_quantity', 'num_prefixes', 'num_suffixes', 'sub_category'], inplace=True, errors='ignore')

# %%
items_f_copy = items_f.copy(deep=True)

# %%
items_f = items_f_copy.copy(deep=True)
items_f = items_f[(items_f.price<=1000) & (items_f.price>=1)]

# %%
y = items_f['price'].values
X = items_f.loc[:, items_f.columns != 'price'].values

# %% [markdown]
# # ML models

# %%
from sklearn.metrics import r2_score, accuracy_score, mean_absolute_error
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm

def print_metrics(y_train, y_train_pred, y_test, y_test_pred):
    print('[R2]\tTrain: {}\tTest: {}'.format(r2_score(y_train, y_train_pred),
                                   r2_score(y_test, y_test_pred)))
    print('[MAE]\tTrain: {}\tTest: {}'.format(mean_absolute_error(y_train, y_train_pred),
                                       mean_absolute_error(y_test, y_test_pred)))

# %%
sc_X = StandardScaler()
sc_y = StandardScaler()

X = sc_X.fit_transform(X)
y = sc_y.fit_transform(y.reshape(-1,1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)

print_metrics(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# [R2]	Train: 0.2929533994836647	Test: -3.7843605865384713e+24
# [MAE]	Train: 0.4341323292041097	Test: 15431058863.79042

# %% [markdown]
# ## backward elimination (r2 score + p value)

# %%
regressor_OLS = sm.OLS(y, X).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0
# x454           0.0432      0.017      2.526      0.012       0.010       0.077
# x455           0.0093      0.020      0.463      0.643      -0.030       0.049
# x456           0.1261      0.039      3.196      0.001       0.049       0.203
# x457           0.0325      0.005      6.257      0.000       0.022       0.043
# x458           0.0022      0.013      0.171      0.864      -0.023       0.027
# x459           0.0073      0.022      0.333      0.739      -0.036       0.051
# x460          -0.0539      0.034     -1.591      0.112      -0.120       0.013
# x461           0.0206      0.019      1.078      0.281      -0.017       0.058
# x462           0.0436      0.025      1.714      0.087      -0.006       0.094
# x463           0.0744      0.028      2.618      0.009       0.019       0.130
# x464          -0.1328      0.071     -1.875      0.061      -0.272       0.006
# x465          -0.0098      0.023     -0.420      0.675      -0.055       0.036
# ==============================================================================
# Omnibus:                    71435.775   Durbin-Watson:                   1.752
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3122971.050
# Skew:                           4.327   Prob(JB):                         0.00
# Kurtosis:                      32.582   Cond. No.                     5.60e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.88e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
def backwardElimination(x, sl):
    stats = []
    
    numVars = len(x[0])
    for i in range(0, numVars):
        a = time.time()
        
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
                    
        b = time.time()            
        print('[{}/{} ({}%) computed in {} seconds]: R2={}, R2_norm={}, Highets P_value:{}'.format(i, numVars, 
            round(i/numVars, 3), int(b-a), round(regressor_OLS.rsquared, 5), round(regressor_OLS.rsquared_adj, 5), 
            round(maxVar, 5)))
        stats.append((regressor_OLS.rsquared, regressor_OLS.rsquared_adj, maxVar))
        
    regressor_OLS.summary()
    return x, stats

SL = 0.05
X_clean, stats = backwardElimination(X, SL)
# Out:
# [0/466 (0.0%) computed in 8 seconds]: R2=0.29533, R2_norm=0.29121, Highets P_value:0.99967
# [1/466 (0.002%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29122, Highets P_value:0.97237
# [2/466 (0.004%) computed in 18 seconds]: R2=0.29533, R2_norm=0.29122, Highets P_value:0.97177
# [3/466 (0.006%) computed in 15 seconds]: R2=0.29533, R2_norm=0.29123, Highets P_value:0.97052
# [4/466 (0.009%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29124, Highets P_value:0.96843
# [5/466 (0.011%) computed in 11 seconds]: R2=0.29533, R2_norm=0.29125, Highets P_value:0.96519
# [6/466 (0.013%) computed in 12 seconds]: R2=0.29533, R2_norm=0.29125, Highets P_value:0.96149
# [7/466 (0.015%) computed in 12 seconds]: R2=0.29533, R2_norm=0.29126, Highets P_value:0.95428
# [8/466 (0.017%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29127, Highets P_value:0.95247
# [9/466 (0.019%) computed in 12 seconds]: R2=0.29533, R2_norm=0.29128, Highets P_value:0.94485
# [10/466 (0.021%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29129, Highets P_value:0.94112
# [11/466 (0.024%) computed in 10 seconds]: R2=0.29533, R2_norm=0.2913, Highets P_value:0.93394
# [12/466 (0.026%) computed in 11 seconds]: R2=0.29533, R2_norm=0.29131, Highets P_value:0.92898
# [13/466 (0.028%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29132, Highets P_value:0.92797
# [14/466 (0.03%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29133, Highets P_value:0.924
# [15/466 (0.032%) computed in 12 seconds]: R2=0.29533, R2_norm=0.29134, Highets P_value:0.92085
# [16/466 (0.034%) computed in 11 seconds]: R2=0.29533, R2_norm=0.29134, Highets P_value:0.91536
# [17/466 (0.036%) computed in 13 seconds]: R2=0.29533, R2_norm=0.29135, Highets P_value:0.90832
# [18/466 (0.039%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29135, Highets P_value:0.90571
# [19/466 (0.041%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29136, Highets P_value:0.88674
# [20/466 (0.043%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29137, Highets P_value:0.88597
# [21/466 (0.045%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29138, Highets P_value:0.88521
# [22/466 (0.047%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29139, Highets P_value:0.87482
# [23/466 (0.049%) computed in 10 seconds]: R2=0.29533, R2_norm=0.2914, Highets P_value:0.87582
# [24/466 (0.052%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29141, Highets P_value:0.87013
# [25/466 (0.054%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29141, Highets P_value:0.86258
# [26/466 (0.056%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29142, Highets P_value:0.84392
# [27/466 (0.058%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29143, Highets P_value:0.84254
# [28/466 (0.06%) computed in 10 seconds]: R2=0.29533, R2_norm=0.29144, Highets P_value:0.84248
# [29/466 (0.062%) computed in 7 seconds]: R2=0.29533, R2_norm=0.29145, Highets P_value:0.83982
# [30/466 (0.064%) computed in 7 seconds]: R2=0.29533, R2_norm=0.29146, Highets P_value:0.83935
# [31/466 (0.067%) computed in 8 seconds]: R2=0.29533, R2_norm=0.29146, Highets P_value:0.83872
# [32/466 (0.069%) computed in 8 seconds]: R2=0.29533, R2_norm=0.29147, Highets P_value:0.83347
# [33/466 (0.071%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29148, Highets P_value:0.8335
# [34/466 (0.073%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29148, Highets P_value:0.83238
# [35/466 (0.075%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29149, Highets P_value:0.82941
# [36/466 (0.077%) computed in 8 seconds]: R2=0.29533, R2_norm=0.2915, Highets P_value:0.82128
# [37/466 (0.079%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29151, Highets P_value:0.81958
# [38/466 (0.082%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29152, Highets P_value:0.81684
# [39/466 (0.084%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29153, Highets P_value:0.80759
# [40/466 (0.086%) computed in 9 seconds]: R2=0.29533, R2_norm=0.29154, Highets P_value:0.80501
# [41/466 (0.088%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29154, Highets P_value:0.81249
# [42/466 (0.09%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29155, Highets P_value:0.78901
# [43/466 (0.092%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29156, Highets P_value:0.78696
# [44/466 (0.094%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29157, Highets P_value:0.78606
# [45/466 (0.097%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29158, Highets P_value:0.78504
# [46/466 (0.099%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29159, Highets P_value:0.76592
# [47/466 (0.101%) computed in 7 seconds]: R2=0.29532, R2_norm=0.29159, Highets P_value:0.76153
# [48/466 (0.103%) computed in 7 seconds]: R2=0.29532, R2_norm=0.2916, Highets P_value:0.96783
# [49/466 (0.105%) computed in 9 seconds]: R2=0.29532, R2_norm=0.2916, Highets P_value:0.75828
# [50/466 (0.107%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29161, Highets P_value:0.75241
# [51/466 (0.109%) computed in 8 seconds]: R2=0.29532, R2_norm=0.29162, Highets P_value:0.75194
# [52/466 (0.112%) computed in 8 seconds]: R2=0.29532, R2_norm=0.29163, Highets P_value:0.7482
# [53/466 (0.114%) computed in 9 seconds]: R2=0.29532, R2_norm=0.29164, Highets P_value:0.7445
# [54/466 (0.116%) computed in 8 seconds]: R2=0.29532, R2_norm=0.29164, Highets P_value:0.74508
# [55/466 (0.118%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29165, Highets P_value:0.74338
# [56/466 (0.12%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29166, Highets P_value:0.73764
# [57/466 (0.122%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29167, Highets P_value:0.73015
# [58/466 (0.124%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29168, Highets P_value:0.72839
# [59/466 (0.127%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29168, Highets P_value:0.72705
# [60/466 (0.129%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29169, Highets P_value:0.72646
# [61/466 (0.131%) computed in 6 seconds]: R2=0.29531, R2_norm=0.2917, Highets P_value:0.72251
# [62/466 (0.133%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29171, Highets P_value:0.7226
# [63/466 (0.135%) computed in 8 seconds]: R2=0.29531, R2_norm=0.29171, Highets P_value:0.72272
# [64/466 (0.137%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29172, Highets P_value:0.71748
# [65/466 (0.139%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29173, Highets P_value:0.71515
# [66/466 (0.142%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29173, Highets P_value:0.71515
# [67/466 (0.144%) computed in 6 seconds]: R2=0.2953, R2_norm=0.29173, Highets P_value:0.71515
# [68/466 (0.146%) computed in 6 seconds]: R2=0.2953, R2_norm=0.29174, Highets P_value:0.71114
# [69/466 (0.148%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29175, Highets P_value:0.70797
# [70/466 (0.15%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29175, Highets P_value:0.69001
# [71/466 (0.152%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29176, Highets P_value:0.69235
# [72/466 (0.155%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29177, Highets P_value:0.68705
# [73/466 (0.157%) computed in 7 seconds]: R2=0.2953, R2_norm=0.29178, Highets P_value:0.65712
# [74/466 (0.159%) computed in 7 seconds]: R2=0.29529, R2_norm=0.29178, Highets P_value:0.64749
# [75/466 (0.161%) computed in 7 seconds]: R2=0.29529, R2_norm=0.29179, Highets P_value:0.64708
# [76/466 (0.163%) computed in 7 seconds]: R2=0.29529, R2_norm=0.2918, Highets P_value:0.64623
# [77/466 (0.165%) computed in 7 seconds]: R2=0.29529, R2_norm=0.29181, Highets P_value:0.64529
# [78/466 (0.167%) computed in 7 seconds]: R2=0.29529, R2_norm=0.29181, Highets P_value:0.63296
# [79/466 (0.17%) computed in 7 seconds]: R2=0.29528, R2_norm=0.29182, Highets P_value:0.62611
# [80/466 (0.172%) computed in 7 seconds]: R2=0.29528, R2_norm=0.29183, Highets P_value:0.62162
# [81/466 (0.174%) computed in 7 seconds]: R2=0.29528, R2_norm=0.29183, Highets P_value:0.61585
# [82/466 (0.176%) computed in 7 seconds]: R2=0.29528, R2_norm=0.29184, Highets P_value:0.61447
# [83/466 (0.178%) computed in 7 seconds]: R2=0.29528, R2_norm=0.29185, Highets P_value:0.60982
# [84/466 (0.18%) computed in 7 seconds]: R2=0.29527, R2_norm=0.29185, Highets P_value:0.60473
# [85/466 (0.182%) computed in 6 seconds]: R2=0.29527, R2_norm=0.29186, Highets P_value:0.59317
# [86/466 (0.185%) computed in 6 seconds]: R2=0.29527, R2_norm=0.29187, Highets P_value:0.59122
# [87/466 (0.187%) computed in 6 seconds]: R2=0.29527, R2_norm=0.29187, Highets P_value:0.58601
# [88/466 (0.189%) computed in 6 seconds]: R2=0.29526, R2_norm=0.29188, Highets P_value:0.56848
# [89/466 (0.191%) computed in 6 seconds]: R2=0.29526, R2_norm=0.29189, Highets P_value:0.56512
# [90/466 (0.193%) computed in 7 seconds]: R2=0.29526, R2_norm=0.29189, Highets P_value:0.55461
# [91/466 (0.195%) computed in 6 seconds]: R2=0.29525, R2_norm=0.2919, Highets P_value:0.54467
# [92/466 (0.197%) computed in 6 seconds]: R2=0.29525, R2_norm=0.2919, Highets P_value:0.54329
# [93/466 (0.2%) computed in 6 seconds]: R2=0.29525, R2_norm=0.29191, Highets P_value:0.54203
# [94/466 (0.202%) computed in 6 seconds]: R2=0.29524, R2_norm=0.29191, Highets P_value:0.53714
# [95/466 (0.204%) computed in 7 seconds]: R2=0.29524, R2_norm=0.29192, Highets P_value:0.5073
# [96/466 (0.206%) computed in 6 seconds]: R2=0.29524, R2_norm=0.29192, Highets P_value:0.50701
# [97/466 (0.208%) computed in 7 seconds]: R2=0.29523, R2_norm=0.29193, Highets P_value:0.50611
# [98/466 (0.21%) computed in 6 seconds]: R2=0.29523, R2_norm=0.29193, Highets P_value:0.50338
# [99/466 (0.212%) computed in 6 seconds]: R2=0.29522, R2_norm=0.29194, Highets P_value:0.49609
# [100/466 (0.215%) computed in 5 seconds]: R2=0.29522, R2_norm=0.29194, Highets P_value:0.48671
# [101/466 (0.217%) computed in 6 seconds]: R2=0.29522, R2_norm=0.29195, Highets P_value:0.48511
# [102/466 (0.219%) computed in 5 seconds]: R2=0.29521, R2_norm=0.29195, Highets P_value:0.48905
# [103/466 (0.221%) computed in 6 seconds]: R2=0.29521, R2_norm=0.29196, Highets P_value:0.48576
# [104/466 (0.223%) computed in 6 seconds]: R2=0.2952, R2_norm=0.29196, Highets P_value:0.48386
# [105/466 (0.225%) computed in 6 seconds]: R2=0.2952, R2_norm=0.29197, Highets P_value:0.48019
# [106/466 (0.227%) computed in 7 seconds]: R2=0.29519, R2_norm=0.29197, Highets P_value:0.47616
# [107/466 (0.23%) computed in 7 seconds]: R2=0.29519, R2_norm=0.29198, Highets P_value:0.47496
# [108/466 (0.232%) computed in 6 seconds]: R2=0.29518, R2_norm=0.29198, Highets P_value:0.46897
# [109/466 (0.234%) computed in 7 seconds]: R2=0.29518, R2_norm=0.29199, Highets P_value:0.46754
# [110/466 (0.236%) computed in 6 seconds]: R2=0.29518, R2_norm=0.29199, Highets P_value:0.46264
# [111/466 (0.238%) computed in 7 seconds]: R2=0.29517, R2_norm=0.29199, Highets P_value:0.45921
# [112/466 (0.24%) computed in 7 seconds]: R2=0.29517, R2_norm=0.292, Highets P_value:0.47545
# [113/466 (0.242%) computed in 7 seconds]: R2=0.29516, R2_norm=0.292, Highets P_value:0.45631
# [114/466 (0.245%) computed in 6 seconds]: R2=0.29516, R2_norm=0.29201, Highets P_value:0.45019
# [115/466 (0.247%) computed in 6 seconds]: R2=0.29515, R2_norm=0.29201, Highets P_value:0.43408
# [116/466 (0.249%) computed in 7 seconds]: R2=0.29515, R2_norm=0.29201, Highets P_value:0.4322
# [117/466 (0.251%) computed in 7 seconds]: R2=0.29514, R2_norm=0.29202, Highets P_value:0.43178
# [118/466 (0.253%) computed in 7 seconds]: R2=0.29513, R2_norm=0.29202, Highets P_value:0.43119
# [119/466 (0.255%) computed in 7 seconds]: R2=0.29513, R2_norm=0.29202, Highets P_value:0.42843
# [120/466 (0.258%) computed in 7 seconds]: R2=0.29512, R2_norm=0.29203, Highets P_value:0.427
# [121/466 (0.26%) computed in 7 seconds]: R2=0.29512, R2_norm=0.29203, Highets P_value:0.41617
# [122/466 (0.262%) computed in 7 seconds]: R2=0.29511, R2_norm=0.29203, Highets P_value:0.41308
# [123/466 (0.264%) computed in 7 seconds]: R2=0.29511, R2_norm=0.29204, Highets P_value:0.41076
# [124/466 (0.266%) computed in 7 seconds]: R2=0.2951, R2_norm=0.29204, Highets P_value:0.40401
# [125/466 (0.268%) computed in 7 seconds]: R2=0.29509, R2_norm=0.29204, Highets P_value:0.39599
# [126/466 (0.27%) computed in 7 seconds]: R2=0.29509, R2_norm=0.29204, Highets P_value:0.39463
# [127/466 (0.273%) computed in 7 seconds]: R2=0.29508, R2_norm=0.29205, Highets P_value:0.39277
# [128/466 (0.275%) computed in 7 seconds]: R2=0.29507, R2_norm=0.29205, Highets P_value:0.392
# [129/466 (0.277%) computed in 7 seconds]: R2=0.29507, R2_norm=0.29205, Highets P_value:0.39004
# [130/466 (0.279%) computed in 6 seconds]: R2=0.29506, R2_norm=0.29205, Highets P_value:0.38282
# [131/466 (0.281%) computed in 7 seconds]: R2=0.29505, R2_norm=0.29206, Highets P_value:0.38116
# [132/466 (0.283%) computed in 6 seconds]: R2=0.29505, R2_norm=0.29206, Highets P_value:0.39064
# [133/466 (0.285%) computed in 6 seconds]: R2=0.29504, R2_norm=0.29206, Highets P_value:0.38069
# [134/466 (0.288%) computed in 7 seconds]: R2=0.29503, R2_norm=0.29206, Highets P_value:0.36317
# [135/466 (0.29%) computed in 7 seconds]: R2=0.29503, R2_norm=0.29206, Highets P_value:0.35213
# [136/466 (0.292%) computed in 6 seconds]: R2=0.29502, R2_norm=0.29207, Highets P_value:0.34673
# [137/466 (0.294%) computed in 7 seconds]: R2=0.29501, R2_norm=0.29207, Highets P_value:0.34486
# [138/466 (0.296%) computed in 6 seconds]: R2=0.295, R2_norm=0.29207, Highets P_value:0.33504
# [139/466 (0.298%) computed in 6 seconds]: R2=0.29499, R2_norm=0.29207, Highets P_value:0.33572
# [140/466 (0.3%) computed in 6 seconds]: R2=0.29499, R2_norm=0.29207, Highets P_value:0.32987
# [141/466 (0.303%) computed in 6 seconds]: R2=0.29498, R2_norm=0.29207, Highets P_value:0.32981
# [142/466 (0.305%) computed in 6 seconds]: R2=0.29497, R2_norm=0.29207, Highets P_value:0.32701
# [143/466 (0.307%) computed in 6 seconds]: R2=0.29496, R2_norm=0.29207, Highets P_value:0.32583
# [144/466 (0.309%) computed in 6 seconds]: R2=0.29495, R2_norm=0.29207, Highets P_value:0.84345
# [145/466 (0.311%) computed in 6 seconds]: R2=0.29495, R2_norm=0.29208, Highets P_value:0.31054
# [146/466 (0.313%) computed in 6 seconds]: R2=0.29494, R2_norm=0.29208, Highets P_value:0.30476
# [147/466 (0.315%) computed in 6 seconds]: R2=0.29493, R2_norm=0.29208, Highets P_value:0.30314
# [148/466 (0.318%) computed in 6 seconds]: R2=0.29492, R2_norm=0.29208, Highets P_value:0.30257
# [149/466 (0.32%) computed in 6 seconds]: R2=0.29491, R2_norm=0.29208, Highets P_value:0.30099
# [150/466 (0.322%) computed in 6 seconds]: R2=0.2949, R2_norm=0.29208, Highets P_value:0.29842
# [151/466 (0.324%) computed in 6 seconds]: R2=0.29489, R2_norm=0.29208, Highets P_value:0.30288
# [152/466 (0.326%) computed in 6 seconds]: R2=0.29488, R2_norm=0.29208, Highets P_value:0.31048
# [153/466 (0.328%) computed in 6 seconds]: R2=0.29488, R2_norm=0.29208, Highets P_value:0.29233
# [154/466 (0.33%) computed in 6 seconds]: R2=0.29487, R2_norm=0.29207, Highets P_value:0.29139
# [155/466 (0.333%) computed in 6 seconds]: R2=0.29486, R2_norm=0.29207, Highets P_value:0.28945
# [156/466 (0.335%) computed in 6 seconds]: R2=0.29485, R2_norm=0.29207, Highets P_value:0.28547
# [157/466 (0.337%) computed in 6 seconds]: R2=0.29483, R2_norm=0.29207, Highets P_value:0.28357
# [158/466 (0.339%) computed in 5 seconds]: R2=0.29482, R2_norm=0.29207, Highets P_value:0.27512
# [159/466 (0.341%) computed in 6 seconds]: R2=0.29481, R2_norm=0.29207, Highets P_value:0.26565
# [160/466 (0.343%) computed in 6 seconds]: R2=0.2948, R2_norm=0.29207, Highets P_value:0.26104
# [161/466 (0.345%) computed in 6 seconds]: R2=0.29479, R2_norm=0.29206, Highets P_value:0.25952
# [162/466 (0.348%) computed in 5 seconds]: R2=0.29478, R2_norm=0.29206, Highets P_value:0.25672
# [163/466 (0.35%) computed in 6 seconds]: R2=0.29477, R2_norm=0.29206, Highets P_value:0.25558
# [164/466 (0.352%) computed in 6 seconds]: R2=0.29476, R2_norm=0.29206, Highets P_value:0.25192
# [165/466 (0.354%) computed in 6 seconds]: R2=0.29475, R2_norm=0.29205, Highets P_value:0.25131
# [166/466 (0.356%) computed in 5 seconds]: R2=0.29473, R2_norm=0.29205, Highets P_value:0.23709
# [167/466 (0.358%) computed in 5 seconds]: R2=0.29472, R2_norm=0.29205, Highets P_value:0.23604
# [168/466 (0.361%) computed in 5 seconds]: R2=0.29471, R2_norm=0.29204, Highets P_value:0.23406
# [169/466 (0.363%) computed in 5 seconds]: R2=0.2947, R2_norm=0.29204, Highets P_value:0.23128
# [170/466 (0.365%) computed in 5 seconds]: R2=0.29468, R2_norm=0.29204, Highets P_value:0.22392
# [171/466 (0.367%) computed in 5 seconds]: R2=0.29467, R2_norm=0.29203, Highets P_value:0.21917
# [172/466 (0.369%) computed in 5 seconds]: R2=0.29466, R2_norm=0.29203, Highets P_value:0.21561
# [173/466 (0.371%) computed in 6 seconds]: R2=0.29464, R2_norm=0.29202, Highets P_value:0.21563
# [174/466 (0.373%) computed in 5 seconds]: R2=0.29463, R2_norm=0.29202, Highets P_value:0.21205
# [175/466 (0.376%) computed in 4 seconds]: R2=0.29461, R2_norm=0.29201, Highets P_value:0.21059
# [176/466 (0.378%) computed in 4 seconds]: R2=0.2946, R2_norm=0.29201, Highets P_value:0.20997
# [177/466 (0.38%) computed in 4 seconds]: R2=0.29459, R2_norm=0.292, Highets P_value:0.20971
# [178/466 (0.382%) computed in 6 seconds]: R2=0.29457, R2_norm=0.292, Highets P_value:0.21442
# [179/466 (0.384%) computed in 5 seconds]: R2=0.29456, R2_norm=0.29199, Highets P_value:0.21034
# [180/466 (0.386%) computed in 5 seconds]: R2=0.29454, R2_norm=0.29199, Highets P_value:0.20769
# [181/466 (0.388%) computed in 5 seconds]: R2=0.29453, R2_norm=0.29198, Highets P_value:0.20367
# [182/466 (0.391%) computed in 5 seconds]: R2=0.29452, R2_norm=0.29198, Highets P_value:0.19602
# [183/466 (0.393%) computed in 5 seconds]: R2=0.2945, R2_norm=0.29197, Highets P_value:0.19924
# [184/466 (0.395%) computed in 4 seconds]: R2=0.29449, R2_norm=0.29196, Highets P_value:0.56741
# [185/466 (0.397%) computed in 5 seconds]: R2=0.29448, R2_norm=0.29197, Highets P_value:0.34836
# [186/466 (0.399%) computed in 4 seconds]: R2=0.29447, R2_norm=0.29197, Highets P_value:0.25248
# [187/466 (0.401%) computed in 4 seconds]: R2=0.29446, R2_norm=0.29197, Highets P_value:0.21149
# [188/466 (0.403%) computed in 4 seconds]: R2=0.29445, R2_norm=0.29196, Highets P_value:0.20077
# [189/466 (0.406%) computed in 4 seconds]: R2=0.29443, R2_norm=0.29196, Highets P_value:0.19795
# [190/466 (0.408%) computed in 4 seconds]: R2=0.29442, R2_norm=0.29195, Highets P_value:0.19592
# [191/466 (0.41%) computed in 4 seconds]: R2=0.2944, R2_norm=0.29195, Highets P_value:0.19595
# [192/466 (0.412%) computed in 4 seconds]: R2=0.29439, R2_norm=0.29194, Highets P_value:0.82551
# [193/466 (0.414%) computed in 4 seconds]: R2=0.29439, R2_norm=0.29195, Highets P_value:0.64089
# [194/466 (0.416%) computed in 4 seconds]: R2=0.29439, R2_norm=0.29195, Highets P_value:0.19466
# [195/466 (0.418%) computed in 4 seconds]: R2=0.29437, R2_norm=0.29195, Highets P_value:0.19061
# [196/466 (0.421%) computed in 4 seconds]: R2=0.29436, R2_norm=0.29194, Highets P_value:0.18334
# [197/466 (0.423%) computed in 4 seconds]: R2=0.29434, R2_norm=0.29194, Highets P_value:0.17729
# [198/466 (0.425%) computed in 4 seconds]: R2=0.29432, R2_norm=0.29193, Highets P_value:0.17439
# [199/466 (0.427%) computed in 4 seconds]: R2=0.29431, R2_norm=0.29192, Highets P_value:0.16865
# [200/466 (0.429%) computed in 4 seconds]: R2=0.29429, R2_norm=0.29191, Highets P_value:0.16608
# [201/466 (0.431%) computed in 4 seconds]: R2=0.29427, R2_norm=0.2919, Highets P_value:0.16093
# [202/466 (0.433%) computed in 4 seconds]: R2=0.29426, R2_norm=0.2919, Highets P_value:0.13992
# [203/466 (0.436%) computed in 4 seconds]: R2=0.29424, R2_norm=0.29188, Highets P_value:0.13823
# [204/466 (0.438%) computed in 4 seconds]: R2=0.29422, R2_norm=0.29187, Highets P_value:0.13548
# [205/466 (0.44%) computed in 4 seconds]: R2=0.2942, R2_norm=0.29186, Highets P_value:0.1336
# [206/466 (0.442%) computed in 4 seconds]: R2=0.29418, R2_norm=0.29185, Highets P_value:0.29274
# [207/466 (0.444%) computed in 4 seconds]: R2=0.29417, R2_norm=0.29185, Highets P_value:0.12907
# [208/466 (0.446%) computed in 4 seconds]: R2=0.29415, R2_norm=0.29184, Highets P_value:0.12645
# [209/466 (0.448%) computed in 4 seconds]: R2=0.29412, R2_norm=0.29183, Highets P_value:0.12687
# [210/466 (0.451%) computed in 4 seconds]: R2=0.2941, R2_norm=0.29181, Highets P_value:0.12499
# [211/466 (0.453%) computed in 4 seconds]: R2=0.29408, R2_norm=0.2918, Highets P_value:0.12163
# [212/466 (0.455%) computed in 4 seconds]: R2=0.29406, R2_norm=0.29179, Highets P_value:0.11329
# [213/466 (0.457%) computed in 4 seconds]: R2=0.29404, R2_norm=0.29178, Highets P_value:0.10975
# [214/466 (0.459%) computed in 4 seconds]: R2=0.29402, R2_norm=0.29176, Highets P_value:0.10714
# [215/466 (0.461%) computed in 4 seconds]: R2=0.29399, R2_norm=0.29175, Highets P_value:0.10671
# [216/466 (0.464%) computed in 4 seconds]: R2=0.29397, R2_norm=0.29173, Highets P_value:0.10524
# [217/466 (0.466%) computed in 3 seconds]: R2=0.29395, R2_norm=0.29172, Highets P_value:0.10924
# [218/466 (0.468%) computed in 3 seconds]: R2=0.29392, R2_norm=0.29171, Highets P_value:0.10748
# [219/466 (0.47%) computed in 3 seconds]: R2=0.2939, R2_norm=0.29169, Highets P_value:0.08986
# [220/466 (0.472%) computed in 3 seconds]: R2=0.29387, R2_norm=0.29167, Highets P_value:0.08481
# [221/466 (0.474%) computed in 4 seconds]: R2=0.29385, R2_norm=0.29166, Highets P_value:0.09137
# [222/466 (0.476%) computed in 3 seconds]: R2=0.29382, R2_norm=0.29164, Highets P_value:0.07882
# [223/466 (0.479%) computed in 3 seconds]: R2=0.29379, R2_norm=0.29162, Highets P_value:0.07704
# [224/466 (0.481%) computed in 3 seconds]: R2=0.29377, R2_norm=0.2916, Highets P_value:0.0757
# [225/466 (0.483%) computed in 3 seconds]: R2=0.29374, R2_norm=0.29158, Highets P_value:0.07286
# [226/466 (0.485%) computed in 3 seconds]: R2=0.29371, R2_norm=0.29156, Highets P_value:0.07046
# [227/466 (0.487%) computed in 3 seconds]: R2=0.29368, R2_norm=0.29154, Highets P_value:0.06532
# [228/466 (0.489%) computed in 3 seconds]: R2=0.29365, R2_norm=0.29152, Highets P_value:0.06668
# [229/466 (0.491%) computed in 3 seconds]: R2=0.29362, R2_norm=0.2915, Highets P_value:0.06358
# [230/466 (0.494%) computed in 3 seconds]: R2=0.29359, R2_norm=0.29148, Highets P_value:0.06638
# [231/466 (0.496%) computed in 3 seconds]: R2=0.29356, R2_norm=0.29146, Highets P_value:0.05909
# [232/466 (0.498%) computed in 3 seconds]: R2=0.29352, R2_norm=0.29143, Highets P_value:0.05788
# [233/466 (0.5%) computed in 3 seconds]: R2=0.29349, R2_norm=0.29141, Highets P_value:0.05779
# [234/466 (0.502%) computed in 3 seconds]: R2=0.29346, R2_norm=0.29139, Highets P_value:0.05253
# [235/466 (0.504%) computed in 3 seconds]: R2=0.29343, R2_norm=0.29136, Highets P_value:0.05344
# [236/466 (0.506%) computed in 3 seconds]: R2=0.29339, R2_norm=0.29134, Highets P_value:0.0505
# [237/466 (0.509%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [238/466 (0.511%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [239/466 (0.513%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [240/466 (0.515%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [241/466 (0.517%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [242/466 (0.519%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [243/466 (0.521%) computed in 2 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [244/466 (0.524%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [245/466 (0.526%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [246/466 (0.528%) computed in 2 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [247/466 (0.53%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [248/466 (0.532%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [249/466 (0.534%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [250/466 (0.536%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [251/466 (0.539%) computed in 2 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [252/466 (0.541%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [253/466 (0.543%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [254/466 (0.545%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [255/466 (0.547%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [256/466 (0.549%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [257/466 (0.552%) computed in 2 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [258/466 (0.554%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [259/466 (0.556%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [260/466 (0.558%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [261/466 (0.56%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [262/466 (0.562%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [263/466 (0.564%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [264/466 (0.567%) computed in 2 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [265/466 (0.569%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [266/466 (0.571%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [267/466 (0.573%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [268/466 (0.575%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [269/466 (0.577%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [270/466 (0.579%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [271/466 (0.582%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [272/466 (0.584%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [273/466 (0.586%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [274/466 (0.588%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [275/466 (0.59%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [276/466 (0.592%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [277/466 (0.594%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [278/466 (0.597%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [279/466 (0.599%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [280/466 (0.601%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [281/466 (0.603%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [282/466 (0.605%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [283/466 (0.607%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [284/466 (0.609%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [285/466 (0.612%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [286/466 (0.614%) computed in 4 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
#
) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [425/466 (0.912%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [426/466 (0.914%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [427/466 (0.916%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [428/466 (0.918%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [429/466 (0.921%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [430/466 (0.923%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [431/466 (0.925%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [432/466 (0.927%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [433/466 (0.929%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [434/466 (0.931%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [435/466 (0.933%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [436/466 (0.936%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [437/466 (0.938%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [438/466 (0.94%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [439/466 (0.942%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [440/466 (0.944%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [441/466 (0.946%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [442/466 (0.948%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [443/466 (0.951%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [444/466 (0.953%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [445/466 (0.955%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [446/466 (0.957%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [447/466 (0.959%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [448/466 (0.961%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [449/466 (0.964%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [450/466 (0.966%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [451/466 (0.968%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [452/466 (0.97%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [453/466 (0.972%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [454/466 (0.974%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [455/466 (0.976%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [456/466 (0.979%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [457/466 (0.981%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [458/466 (0.983%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [459/466 (0.985%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [460/466 (0.987%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [461/466 (0.989%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [462/466 (0.991%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [463/466 (0.994%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [464/466 (0.996%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745
# [465/466 (0.998%) computed in 3 seconds]: R2=0.29336, R2_norm=0.29131, Highets P_value:0.04745

# %% [markdown]
# ## RandomForest with 10 trees

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train,  y_train.ravel())

y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)

print_metrics(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# [R2]	Train: 0.8759291161516278	Test: 0.3033642970240694
# [MAE]	Train: 0.14629374327204797	Test: 0.37251095701000647

# %% [markdown]
# ### with KFold train test

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=0)
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)

metrics = []
for train_index, test_index in kf.split(X):
    print('.', end='')
    
    X_train, X_test = X_clean[train_index], X_clean[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    regressor.fit(X_train, y_train.ravel())

    y_train_pred = regressor.predict(X_train)
    y_test_pred = regressor.predict(X_test)
    
    metrics.append((r2_score(y_train, y_train_pred), r2_score(y_test, y_test_pred)))

print(np.mean([v1 for v1, v2 in metrics]), np.std([v1 for v1, v2 in metrics]))
print(np.mean([v2 for v1, v2 in metrics]), np.std([v2 for v1, v2 in metrics]))
# Out:
# ..........0.8798749637390257 0.0019064147262380323
# 0.3258246892409187 0.03351033651596367

# %% [markdown]
# ### backward elimination (R2 score + p value)

# %%
import statsmodels.formula.api as sm
def backwardElimination(x, sl):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                    x = np.delete(x, j, 1)
    regressor_OLS.summary()
    return x

SL = 0.05
X_opt = X[:, [0, 1, 2, 3, 4, 5]]
X_Modeled = backwardElimination(X_opt, SL)

# %% [markdown]
# ### RandomForest with 100 trees

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X_train, y_train)

y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)
print_metrics(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# /home/fabio/.conda/envs/main/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.2763365525206958

# %% [markdown]
# ## SVR

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train.ravel())

y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)
print_metrics(y_train, y_train_pred, y_test, y_test_pred)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'poly', degree=2)
regressor.fit(X_train, y_train.ravel())

y_train_pred = regressor.predict(X_train)
y_test_pred = regressor.predict(X_test)
print_metrics(y_train, y_train_pred, y_test, y_test_pred)
# Out:
# /home/fabio/.conda/envs/main/lib/python3.7/site-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
